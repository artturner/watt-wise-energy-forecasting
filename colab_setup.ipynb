# %% [markdown]
# # ⚙️ Watt Wise: Google Colab Setup
#
# This notebook will install required packages and prepare your Colab environment for the Watt Wise project.

# %%
# 📦 Install dependencies
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn statsmodels streamlit xgboost
# Optional: Uncomment if using deep learning
# !pip install tensorflow

# %%
# 🔄 (Optional) Clone the GitHub repo
# Replace with your actual repo URL once it's available
# !git clone https://github.com/YOUR_USERNAME/watt-wise-energy-forecasting.git

# %%
# 💾 (Optional) Mount Google Drive to save outputs or models
from google.colab import drive
drive.mount('/content/drive')
